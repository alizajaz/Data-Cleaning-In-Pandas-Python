# %%
#Data Cleaning in Pandas
import pandas as pd
df = pd.read_excel(r"C:\Users\Admin\Desktop\Data Analyst  Project\Python\Data Cleaning in Pandas\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop(columns="Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"].str.strip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.strip("...")
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.strip("/")
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"]= df["Last_Name"].str.lstrip("...")
df["Last_Name"]= df["Last_Name"].str.lstrip("/")
df["Last_Name"]= df["Last_Name"].str.rstrip("_")

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#you can put all in one string 
df["Last_Name"]= df["Last_Name"].str.rstrip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
#df ["Phone_Number"].apply(lambda x: x[0:3] +'-'+ x[3:6] + '-' + x[6:10])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22944\578390125.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
# 0     1235455421
# 1     1236439775
# 2            nan
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           nan
# 11           nan
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           nan
# 18            Na
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
 #changing to number to string
    df["Phone_Number"].apply(lambda x: str(x))
# Out:
# 0     1235455421
# 1     1236439775
# 2            nan
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           nan
# 11           nan
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           nan
# 18            Na
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df ["Phone_Number"].apply(lambda x: x[0:3] +'-'+ x[3:6] + '-' + x[6:10])
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2            nan--
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6            nan--
# 7     876-678-3469
# 8             Na--
# 9     123-545-5421
# 10           nan--
# 11           nan--
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17           nan--
# 18            Na--
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
#df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
df["Phone_Number"] =df ["Phone_Number"].apply(lambda x: x[0:3] +'-'+ x[3:6] + '-' + x[6:10])
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White       nan----
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger       nan----
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf         NaN        Na----
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee       nan----
# 11        1012      Harry      Potter       nan----
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# ...

# %%
#get rid of nan na
df["Phone_Number"]=df["Phone_Number"].str.replace('nan--','')
df["Phone_Number"]=df["Phone_Number"].str.replace('Na--','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# ...

# %%
#address
df[["Street_Address","State","Zip_Code"]] = df["Address"].str.split(',',2,expand=True)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22944\4067343554.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[["Street_Address","State","Zip_Code"]] = df["Address"].str.split(',',2,expand=True)
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# ...

# %%
df["Paying Customer"]=df["Paying Customer"].str.replace('Yes','Y')
df["Paying Customer"]=df["Paying Customer"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# ...

# %%
#df= df.replace('N/a','')
#df= df.replace('NaN','')
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf                        --
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# ...

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact']=='Y':
        df.drop(x,inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf                        --
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# 17        1018      Clark        Kent            --
# ...

# %%
for x in df.index:
    if df.loc[x,'Phone_Number']=='':
        df.drop(x,inplace=True)
df
#df.dropna(subset="Phone_Number"),inplace=True) another way to drop values
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 4         1005        Jon        Snow  876--67-8-34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876--67-8-34
# 8         1009    Gandalf                        --
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876--67-8-34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123--64-3-97
# 17        1018      Clark        Kent            --
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123--64-3-97
# 2         1003     Walter       White            --
# 3         1005        Jon        Snow  876--67-8-34
# 4         1006        Ron     Swanson  304--76-2-24
# 5         1007       Jeff      Winger            --
# 6         1008   Sherlock      Holmes  876--67-8-34
# 7         1009    Gandalf                        --
# 8         1010      Peter      Parker  123--54-5-54
# 9         1011    Samwise      Gamgee            --
# 10        1012      Harry      Potter            --
# 11        1013        Don      Draper  123--54-3-23
# 12        1014     Leslie       Knope  876--67-8-34
# 13        1015       Toby  Flenderson  304--76-2-24
# 14        1016        Ron     Weasley  123--54-5-54
# 15        1017   Michael        Scott  123--64-3-97
# 16        1018      Clark        Kent            --
# ...
